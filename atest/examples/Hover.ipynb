# %%
def python_add(a: int, b: int):
    """Add documentation"""
    return


python_add(1, 2)

# %%
# %%javascript
# function js_add(a, b) {
#     return a + b
# }
#
# js_add(1, 2)

# %%
# %%javascript
# Math

# %%
import math
z = math.atan2(0.4, 0.3)
